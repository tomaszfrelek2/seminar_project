# %%
# %pip install "ultralytics<=8.3.40"
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.40 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 43.0/112.6 GB disk)

# %%
# !yolo task=detect mode=train model=yolo11s.pt data= /content/datasets/mud-1/data.yaml epochs=10 imgsz=512 plots=True
# Out:
# /content
# ...
# 100% 18.4M/18.4M [00:00<00:00, 203MB/s]
# New https://pypi.org/project/ultralytics/8.3.116 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.40 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...
