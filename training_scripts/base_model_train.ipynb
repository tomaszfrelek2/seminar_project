# %%
# %pip install "ultralytics<=8.3.40"
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.40 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 43.1/112.6 GB disk)

# %%
# !yolo task=detect mode=train model=yolo11s.pt data= /content/datasets/My-First-Project-1/data.yaml epochs=10 imgsz=512 plots=True
# Out:
# /content
# ...
# 100% 18.4M/18.4M [00:00<00:00, 206MB/s]
# New https://pypi.org/project/ultralytics/8.3.105 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.40 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from IPython.display import Image as IPyImage

IPyImage(filename=f'{HOME}/runs/detect/train/confusion_matrix.png', width=600)

# %%
from IPython.display import Image as IPyImage

IPyImage(filename=f'{HOME}/runs/detect/train/results.png', width=600)

# %%
# !yolo task=detect mode=val model={HOME}/runs/detect/train/weights/best.pt data=/content/datasets/My-First-Project-1/data.yaml
# Out:
# Ultralytics 8.3.40 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11s summary (fused): 238 layers, 9,417,057 parameters, 0 gradients, 21.3 GFLOPs
# val: Scanning /content/datasets/My-First-Project-1/valid/labels.cache... 2627 images, 0 backgrounds, 0 corrupt: 100% 2627/2627 [00:00<?, ?it/s]
# val: WARNING ⚠️ /content/datasets/My-First-Project-1/valid/images/1478021875081281646_jpg.rf.0e515ea880a6fac002348de7f843fb7f.jpg: 1 duplicate labels removed
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 165/165 [00:27<00:00,  5.95it/s]
#                    all       2627      19252       0.83      0.596      0.661      0.376
#                  biker        242        339      0.742      0.617      0.674      0.378
#                    car       2568      12563      0.857      0.805      0.854      0.568
#             pedestrian        699       2193      0.762      0.541      0.633      0.306
# ...
